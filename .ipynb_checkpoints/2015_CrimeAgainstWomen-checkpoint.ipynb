# %% [markdown]
# # Data Preprocessing

# %%
# importing libraries
import numpy as np
import pandas as pd
import re

# %%
data = pd.read_csv(r"C:\Users\Hp\OneDrive\Documents\Mansi\Research\CrimeAgainstWomen\dataset\CrimeAgainstWomenStateWise2015.csv")

# %%
data.columns
# Out:
# Index(['Category (Col. 1)', 'State/UT (Col. 2)',
#        'Mid-Year Projected Female Population(In Lakhs) (Col. 3)',
#        'Rape (Section 376 IPC) - Rape (Total) - I (Col. 4)',
#        'Rape (Section 376 IPC) - Rape (Total) - V (Col. 5)',
#        'Rape (Section 376 IPC) - Rape (Total) - R (Col. 6)',
#        'Rape (Section 376 IPC) - Custodial Rape - Custodial Rape (Total) - I (Col. 7)',
#        'Rape (Section 376 IPC) - Custodial Rape - Custodial Rape (Total) - V (Col. 8)',
#        'Rape (Section 376 IPC) - Custodial Rape - Custodial Rape (Total) - R (Col. 9)',
#        'Rape (Section 376 IPC) - Custodial Rape - Gang Rape - I (Col. 10)',
#        ...
#        'Immoral Traffic (Prevention) Act - Under ITP Section 7 - R (Col. 114)',
#        'Immoral Traffic (Prevention) Act - Under ITP Section 8 - I (Col. 115)',
#        'Immoral Traffic (Prevention) Act - Under ITP Section 8 - V (Col. 116)',
#        'Immoral Traffic (Prevention) Act - Under ITP Section 8 - R (Col. 117)',
# ...

# %% [raw]
# # Different categories of crime against women
# Rape
# Custodial Rape
# Gang Rape
# Attempt to Commit Rape
# Kidnapping
# Abduction
# Dowry Deaths
# Assault
# Sexual Harassment
# Voyeurism
# Stalking
# Insult to Modesty
# Cruelty
# Importation of Girls from Foreign Country
# Abetment of Suicide
# Indecent Representation of Women
# Commission of Sati
# Domestic Violence
# Immoral Traffic Prevention

# %%
data.head()
# Out:
#   Category (Col. 1)  State/UT (Col. 2)  \
# 0             State     Andhra Pradesh
# 1             State  Arunachal Pradesh
# 2             State              Assam
# 3             State              Bihar
# 4             State       Chhattisgarh
#
#    Mid-Year Projected Female Population(In Lakhs) (Col. 3)  \
# 0                                              255.6
# 1                                                6.2
# 2                                              157.0
# 3                                              498.4
# 4                                              127.8
#
#    Rape (Section 376 IPC) - Rape (Total) - I (Col. 4)  \
# 0                                               1027
# 1                                                 71
# 2                                               1733
# 3                                               1041
# 4                                               1560
#
#    Rape (Section 376 IPC) - Rape (Total) - V (Col. 5)  \
# ...
